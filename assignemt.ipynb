# %%
#ASSIGNMENT
#Q1.. WhAT IS AN EXCEPTION IN PYTHON?WRITE THE DIFFERENCES BETWEEN EXCEPTIONS AND SYNTAX ERROR?
#In Python, an exception is an event that occurs during the execution of a program that disrupts the normal flow of the program's instructions. Exceptions are used to handle errors and unexpected situations in a more controlled manner. They allow you to gracefully deal with problems that might otherwise cause your program to crash.
#Here are the key differences between exceptions and syntax errors in Python:
#Exception:
#Exceptions occur during the runtime of a program when a specific error condition is encountered.
#They are raised by the Python interpreter or by the code you write using the raise statement.
#Examples of exceptions include ZeroDivisionError, ValueError, FileNotFoundError, and custom exceptions you define in your code.
#You can catch and handle exceptions using try and except blocks to prevent the program from crashing and to perform error-specific actions.
#Syntax Error:
#Syntax errors occur during the parsing of your code, before it is executed. They are also known as parsing errors.
#They are caused by violations of the language's syntax rules, such as missing colons, incorrect indentation, or misspelled keywords.
#Syntax errors prevent the program from running at all. The code must be fixed before it can be executed.
#Examples of syntax errors include missing parentheses, incorrect variable names, and improper indentation.
#Q2.WHAT HAPPENS WHEN AN EXCEPTION IS NOT HANDLED?EXPLAIN WITH AN EXAMPLE?
#ANS-When an exception is not handled in a Python program, it leads to an abnormal termination of the program. In such a case, Python prints an error message, known as a traceback, to the console, indicating the type of exception that occurred and the location in the code where it occurred. This traceback provides information about the call stack and the sequence of function calls that led to the exception.
#def divide(a, b):
    #return a / b


    #result = divide(10, 0)  # Attempt to divide by zero
   # print("Result:", result)
#except ZeroDivisionError as e:
   # print("Error:", e)
    #In this example, we have a divide function that attempts to divide a number by another number. However, in the try block, we are attempting to divide by zero, which is not allowed in mathematics and will raise a ZeroDivisionError.
#Q3.WHICH PYTHON STATEMENTS ARE USED TO CATCH AND HANDLE EXCEPTIONS?EXPLAIN WITH AN EXAMPLE?
#In Python, you can use the try and except statements to handle exceptions. The try block is used to enclose the code where an exception might occur, and the except block is used to specify how to handle the exception if it occurs. Here's an explanation with an example:
#try:
    # Code that might raise an exception
   # result = 10 / 0  # Attempting to divide by zero
#except ZeroDivisionError as e:
    # Code to handle the exception
   # print("An error occurred:", e)
#In this example, we have:

# The try block, which contains the code that might raise an exception. In this case, we are attempting to divide the number 10 by zero, which will raise a ZeroDivisionError.

# The except block, which specifies how to handle the exception. Here, we catch the ZeroDivisionError and assign it to the variable e. Then, we print an error message along with the exception message.

# When you run this code, here's what happens:

# The program enters the try block and executes the code within it.

# An exception is raised because we cannot divide by zero.

# Since we have an except block that specifically handles ZeroDivisionError, Python jumps to that block.

# In the except block, we print an error message along with the exception message (which contains information about the error).

# The output will be:

# vbnet
# Copy code
# An error occurred: division by zero
# This demonstrates how the try and except statements work together to catch and handle exceptions. You can have multiple except blocks to handle different types of exceptions or a general except block to catch any unexpected exceptions. Additionally, you can use the else and finally blocks in combination with try and except to further control the flow of your exception handling code.

#Q4.EXPLAIN WITH AN EXAMPLE
#TRY AND ELSE
#FINALLY
#RAISE
#Certainly! Let's explain the use of try, except, else, and finally blocks in Python with an example:


# try:
#     # Code that may raise an exception
#     result = 10 / 2  # This division should succeed
# except ZeroDivisionError as e:
#     # Code to handle the ZeroDivisionError exception
#     print("Error:", e)
# else:
#     # Code to run if no exception occurs
#     print("No exceptions occurred. Result:", result)
# finally:
#     # Code to run regardless of whether an exception occurred
#     print("Finally block executed.")
# In this example:

# The try block contains code that performs a division operation, which should succeed without raising any exceptions since we are dividing by 2.

# The except block specifies what to do if a ZeroDivisionError exception occurs. However, since we are not dividing by zero in this case, this block will not be executed.

# The else block contains code that will run if no exceptions occur within the try block. In this case, it prints a message along with the result of the division.

# The finally block contains code that will run regardless of whether an exception occurred. It is used for cleanup or resource release tasks. In this example, it simply prints a message.

# When you run this code:

# The program enters the try block and successfully calculates the result of 10 / 2, which is 5.

# Since no exceptions occurred, the except block is skipped.

# The program enters the else block and prints the message "No exceptions occurred. Result: 5".

# Finally, the program enters the finally block and prints "Finally block executed."

# The output will be:

# rust
# No exceptions occurred. Result: 5
# Finally block executed.
# This example demonstrates how you can use the try, except, else, and finally blocks together to handle exceptions gracefully while ensuring that certain code (such as cleanup operations) always runs, regardless of whether an exception occurs.


#Q5.what are custom exceptions in python?why do we need custom exceptions ?explain with an example?
#ansCustom exceptions, also known as user-defined exceptions, are exceptions that you define in your Python code to handle specific error conditions that are not adequately represented by the built-in exceptions provided by Python. These exceptions allow you to create more expressive and meaningful error handling in your code.

# Here's why you might need custom exceptions and an example to illustrate their use:

# Why do we need Custom Exceptions:

# Expressiveness: Custom exceptions allow you to create exceptions with names that describe the specific error condition more accurately, making your code more readable and self-explanatory.

# Modularity: They help in modularizing error handling code. Instead of scattering error handling logic throughout your codebase, you can centralize it within custom exception classes, making your code easier to maintain.

# Granularity: Custom exceptions can be designed to represent different error scenarios within your application, providing a finer level of control over how different errors are handled.

# Abstraction: You can encapsulate details of error handling and provide a higher-level interface for error management, making your code more abstract and easier to work with.

# Example:

# Suppose you're building a banking application, and you want to handle the scenario where a user tries to withdraw more money from their account than they have available. You could define a custom exception for this situation:

# python
# Copy code
# class InsufficientFundsError(Exception):
#     """Custom exception for insufficient funds."""
#     def __init__(self, balance, amount):
#         self.balance = balance
#         self.amount = amount
#         super().__init__(f"Insufficient funds: Balance is {balance}, but attempted to withdraw {amount}")
# Now, you can use this custom exception in your code:

# python
# Copy code
# def withdraw(account_balance, amount):
#     if account_balance < amount:
#         raise InsufficientFundsError(account_balance, amount)
#     else:
#         # Perform the withdrawal
#         account_balance -= amount
#         return account_balance

# try:
#     balance = 100
#     amount_to_withdraw = 150
#     new_balance = withdraw(balance, amount_to_withdraw)
#     print(f"Withdrawal successful. New balance: {new_balance}")
# except InsufficientFundsError as e:
#     print(f"Error: {e}")
# In this example:

# We define a custom exception InsufficientFundsError, which inherits from the base Exception class. This exception takes the current balance and the withdrawal amount as arguments.

# In the withdraw function, if the withdrawal amount exceeds the account balance, we raise the InsufficientFundsError with an informative error message.

# In the try block, we attempt a withdrawal and handle the custom exception if it occurs.

# Using custom exceptions in this way allows you to create a more structured and informative error-handling mechanism tailored to the specific needs of your application.
#q6.create a custom exception class use this class to handle an exception?
#To create a custom exception class in Python, you can define a new class that inherits from the built-in Exception class or one of its subclasses (e.g., ValueError, TypeError, or RuntimeError). Here's an example of creating a custom exception class and then using it to handle an exception:

# python
# Copy code
# # Define a custom exception class
# class CustomError(Exception):
#     def __init__(self, message):
#         super().__init__(message)

# # Function that raises the custom exception
# def divide(a, b):
#     if b == 0:
#         raise CustomError("Division by zero is not allowed.")
#     return a / b

# try:
#     result = divide(10, 0)  # Attempt to divide by zero
#     print("Result:", result)
# except CustomError as e:
#     print("Custom exception occurred:", e)
# In this example:

# We define a custom exception class called CustomError, which inherits from the base Exception class. It takes a message argument that can be used to provide a custom error message.

# The divide function attempts to divide a number a by another number b. If b is zero, it raises a CustomError exception with the message "Division by zero is not allowed."

# In the try block, we call the divide function with 10 and 0 as arguments, which triggers the custom exception since we're trying to divide by zero.

# The except block catches the CustomError exception and prints the custom error message provided when the exception was raised.

# When you run this code, you will see the following output:

# vbnet
# Copy code
# Custom exception occurred: Division by zero is not allowed.
# This demonstrates how to create a custom exception class and use it to handle specific error conditions in your code. You can customize your custom exception class to include additional attributes or methods as needed to provide more context about the error or to facilitate error handling.
